# %% [markdown]
# # ASSOCIATION RULES

# %% [markdown]
# Data Preprocessing:
#
# Pre-process the dataset to ensure it is suitable for Association rules, this may include handling missing values, removing duplicates, and converting the data to appropriate format.

# %%
import pandas as pd
dataset  = pd.read_excel('/content/Online retail.xlsx',sheet_name = 'Sheet1',names = ['itemsets'])
dataset
# Out:
#                                                itemsets
# 0                                burgers,meatballs,eggs
# 1                                               chutney
# 2                                        turkey,avocado
# 3     mineral water,milk,energy bar,whole wheat rice...
# 4                                        low fat yogurt
# ...                                                 ...
# 7495                      butter,light mayo,fresh bread
# 7496  burgers,frozen vegetables,eggs,french fries,ma...
# 7497                                            chicken
# 7498                                 escalope,green tea
# 7499    eggs,frozen smoothie,yogurt cake,low fat yogurt
#
# [7500 rows x 1 columns]

# %%
dataset.duplicated().sum()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0

# %%
dataset[dataset.duplicated()]
# Out:
#                  itemsets
# 33                cookies
# 41              spaghetti
# 59              spaghetti
# 63            turkey,eggs
# 64           french fries
# ...                   ...
# 7490        herb & pepper
# 7491   chocolate,escalope
# 7494  pancakes,light mayo
# 7497              chicken
# 7498   escalope,green tea
#
# [2325 rows x 1 columns]

# %%
dataset = dataset.drop_duplicates()
dataset
# Out:
#                                                itemsets
# 0                                burgers,meatballs,eggs
# 1                                               chutney
# 2                                        turkey,avocado
# 3     mineral water,milk,energy bar,whole wheat rice...
# 4                                        low fat yogurt
# ...                                                 ...
# 7492  burgers,salmon,pancakes,french fries,frozen sm...
# 7493  turkey,burgers,dessert wine,shrimp,pasta,tomat...
# 7495                      butter,light mayo,fresh bread
# 7496  burgers,frozen vegetables,eggs,french fries,ma...
# 7499    eggs,frozen smoothie,yogurt cake,low fat yogurt
#
# [5175 rows x 1 columns]

# %% [markdown]
# scaling the data

# %% [markdown]
# **Association Rule Mining:**
#
# Implement an Apriori algorithm using tool like python with libraries such as Pandas and Mlxtend etc.
#
#  Apply association rule mining techniques to the pre-processed dataset to discover interesting relationships between products purchased together.
#
# Set appropriate threshold for support, confidence and lift to extract meaning full rules.

# %%
from mlxtend.preprocessing import TransactionEncoder

Trans_enco = TransactionEncoder()
scaled_data = Trans_enco.fit(dataset).transform(dataset)
scaled_data
# Out:
# array([[ True,  True,  True,  True,  True],
#        [False, False, False, False, False],
#        [False, False, False, False, False],
#        ...,
#        [False, False, False, False, False],
#        [False, False, False, False, False],
#        [False, False, False, False, False]])

# %%
Trans_enco.columns_
# Out:
# ['e', 'i', 'm', 's', 't']

# %%
df = pd.DataFrame(scaled_data, columns = Trans_enco.columns_)
df
# Out:
#           e      i      m      s      t
# 0      True   True   True   True   True
# 1     False  False  False  False  False
# 2     False  False  False  False  False
# 3     False  False  False  False  False
# 4     False  False  False  False  False
# ...     ...    ...    ...    ...    ...
# 5170  False  False  False  False  False
# 5171  False  False  False  False  False
# 5172  False  False  False  False  False
# 5173  False  False  False  False  False
# 5174  False  False  False  False  False
#
# [5175 rows x 5 columns]

# %% [markdown]
# creating a  model

# %%
from mlxtend.frequent_patterns import apriori
frequent_itemsets = apriori(df , min_support = 0.1 , use_colnames = True)
frequent_itemsets
# Out:
# Empty DataFrame
# Columns: [support, itemsets]
# Index: []

# %%
# Apply apriori algorithm on transformed dataset with given confidence and support value
frequent_itemsets = apriori(df, min_support=0.1,max_len=2, use_colnames = False)
frequent_itemsets
# rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=.20)
# rules.head(20)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Empty DataFrame
# Columns: [support, itemsets]
# Index: []

# %%
# ass_rule = association_rules(frequent_itemsets, metric="confidence", min_threshold=.20)
# ass_rule

# %% [markdown]
# after we applying the apriori algorithm the dataset is empty
# Due to empty dataset we cant find confidence and lift ratio etc

# %% [markdown]
# # Interview questions

# %% [markdown]
# # 1.What is lift and why is it important in Association rules?

# %% [markdown]
# Lift is commonly used in market basket analysis, and measures the strength of a rule by comparing the observed co-occurrence of items to their expected co-occurrence if they were independent of each other.
# Lift is important to measure the Strength of Association.It detects interesting rules the rules that have a higher-than-expected association.It is useful in recommendation systems.

# %% [markdown]
# # 2.What is support and Confidence. How do you calculate them?

# %% [raw]
# 1. Support:
# Support measures how frequently an itemset appears in the dataset. It gives an idea of how popular or frequent a particular combination of items is in all transactions.
# Formula for Support:
# Support(A)=Number of Transactions Containing A / Total Number of Transactions
# 2. Confidence:
# Confidence measures how often the rule A⇒B holds true, given that the antecedent A has occurred.
# Formula for Confidence:
# Confidence(A⇒B)=Support(A∩B) / Support(A)

# %% [markdown]
# # 3.What are some limitations or challenges of Association rules mining?

# %% [raw]
# Challenges:
# 1.Association rule mining can generate an overwhelming number of rules, especially when the   dataset is large and dense.
# 2.Setting the right values for minimum support and confidence is a common challenge. If thresholds are too high, interesting rules might be excluded. If they are too low, too many rules are generated, including irrelevant or trivial ones.
# 3.Used in handling large datasets.
# Limitations:
# 1.The sheer volume of generated rules makes it difficult to interpret or analyze all of them, and it becomes hard to filter out the most useful and actionable ones.
# 2.If the minimum support threshold is set too high, rules that might be of interest are missed. If it's set too low, the algorithm may generate an excessive number of rules, including irrelevant ones.
# 3.As the dataset size increases, algorithms like Apriori and FP-Growth can become inefficient, requiring more computational resources and time.
